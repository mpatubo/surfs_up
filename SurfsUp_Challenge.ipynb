# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import pandas as pd

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
session

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June.

# %%
#2 refactor
#filter(extract('month', Foo.Date) == 12)
results_precip_june = session.query(Measurement.date, Measurement.prcp, Measurement.tobs).filter(extract('month', Measurement.date) == 6)

# %%
print(results_precip_june.all())
# Out:
# [('2010-06-01', 0.0), ('2010-06-02', 0.01), ('2010-06-03', 0.0), ('2010-06-04', 0.0), ('2010-06-05', 0.0), ('2010-06-06', 0.0), ('2010-06-07', 0.0), ('2010-06-08', 0.0), ('2010-06-09', 0.0), ('2010-06-10', 0.0), ('2010-06-11', 0.0), ('2010-06-12', 0.0), ('2010-06-13', 0.0), ('2010-06-14', 0.0), ('2010-06-15', 0.0), ('2010-06-16', 0.0), ('2010-06-17', 0.0), ('2010-06-18', 0.0), ('2010-06-19', 0.0), ('2010-06-20', 0.0), ('2010-06-21', 0.0), ('2010-06-22', 0.0), ('2010-06-23', 0.0), ('2010-06-24', 0.0), ('2010-06-25', 0.0), ('2010-06-26', 0.02), ('2010-06-27', 0.0), ('2010-06-28', 0.0), ('2010-06-29', 0.0), ('2010-06-30', 0.0), ('2011-06-01', 0.07), ('2011-06-02', 0.0), ('2011-06-03', 0.56), ('2011-06-04', 0.89), ('2011-06-05', 0.0), ('2011-06-06', 0.0), ('2011-06-07', 0.0), ('2011-06-08', 0.03), ('2011-06-09', 0.01), ('2011-06-10', 0.0), ('2011-06-11', 0.0), ('2011-06-12', 0.0), ('2011-06-13', 0.0), ('2011-06-14', 0.0), ('2011-06-15', 0.0), ('2011-06-17', 0.0), ('2011-06-18', 0.0), ('2
# ...

# %%
#  3. Convert the June temperatures to a list.

df_june = pd.DataFrame(results_precip_june, columns=['date','precipitation', 'temperature'])
df_june.set_index(df_june['date'], inplace=True)

# %%
df_june.head()
# Out:
#                   date  precipitation  temperature
# date
# 2010-06-01  2010-06-01           0.00         78.0
# 2010-06-02  2010-06-02           0.01         76.0
# 2010-06-03  2010-06-03           0.00         78.0
# 2010-06-04  2010-06-04           0.00         76.0
# 2010-06-05  2010-06-05           0.00         77.0

# %%
df_june.describe()
# Out:
#        precipitation  temperature
# count    1574.000000  1700.000000
# mean        0.136360    74.944118
# std         0.335731     3.257417
# min         0.000000    64.000000
# 25%         0.000000    73.000000
# 50%         0.020000    75.000000
# 75%         0.120000    77.000000
# max         4.430000    85.000000

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
#see above

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.

results_precip_dec = session.query(Measurement.date, Measurement.prcp, Measurement.tobs).filter(extract('month', Measurement.date) == 12)

# %%
# 7. Convert the December temperatures to a list.
df_precip_dec = pd.DataFrame(results_dec, columns=['date','precipitation', 'temperature'])
df_precip_dec.set_index(df_precip_dec['date'], inplace=True)

# %%
results_dec

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df = pd.DataFrame(results_dec, columns=['date', 'precipitation', 'temperatures'])

# %%
print(results_precip_dec.all())
# Out:
# [('2010-12-01', 0.04, 76.0), ('2010-12-03', 0.0, 74.0), ('2010-12-04', 0.0, 74.0), ('2010-12-06', 0.0, 64.0), ('2010-12-07', 0.0, 64.0), ('2010-12-08', 0.0, 67.0), ('2010-12-09', 0.0, 77.0), ('2010-12-10', 1.58, 66.0), ('2010-12-11', 0.77, 69.0), ('2010-12-12', 0.0, 68.0), ('2010-12-13', 0.0, 68.0), ('2010-12-14', 0.0, 71.0), ('2010-12-15', 0.0, 74.0), ('2010-12-16', 0.0, 67.0), ('2010-12-17', 0.0, 66.0), ('2010-12-18', 0.0, 69.0), ('2010-12-19', 1.4, 71.0), ('2010-12-23', 0.0, 70.0), ('2010-12-24', 0.0, 70.0), ('2010-12-26', None, 74.0), ('2010-12-27', 0.13, 74.0), ('2010-12-28', 0.55, 71.0), ('2010-12-29', 0.06, 75.0), ('2010-12-30', 0.01, 75.0), ('2010-12-31', 0.0, 72.0), ('2011-12-01', 0.03, 69.0), ('2011-12-02', 0.08, 68.0), ('2011-12-03', 0.0, 73.0), ('2011-12-04', 0.0, 74.0), ('2011-12-05', 0.0, 73.0), ('2011-12-06', 0.0, 73.0), ('2011-12-07', 0.0, 73.0), ('2011-12-08', 0.0, 73.0), ('2011-12-09', 0.13, 71.0), ('2011-12-10', 0.07, 73.0), ('2011-12-11', 0.07, 73.0), ('2011-12-12
# ...

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df.describe()
# Out:
#        precipitation  temperatures
# count    1405.000000   1517.000000
# mean        0.216819     71.041529
# std         0.541399      3.745920
# min         0.000000     56.000000
# 25%         0.000000     69.000000
# 50%         0.030000     71.000000
# 75%         0.150000     74.000000
# max         6.420000     83.000000
